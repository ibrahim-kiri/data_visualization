# %%
import matplotlib.pyplot as plt
# Out:
# Running cells with '.venv (3.12.3) (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/ibrahim/Desktop/python/data_visualization/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
squares = [1, 4, 9, 16, 25]

fig, ax = plt.subplots()
ax.plot(squares)

plt.show()
